# %%
import pandas as pd
from IPython.display import display, HTML

# %%
outlets = pd.read_csv("Data/QSR_outlet_dataset.csv")
socioeconomic = pd.read_csv('Data/QSR_socioeconomic_dataset.csv')

# %%
outlets.loc[outlets['Brand'].str.contains('five', case=False)].shape[0]
# Out:
# 10

# %%
outlets.loc[outlets['Brand'].str.contains('five', case=False), 'Brand'] = "Five Guys"

# %%
outlets[outlets['Brand'].str.contains('five',case=False)]
# Out:
#      Outlet ID      Brand     Region Province Province_Shorthand  \
# 972        978  Five Guys   Piemonte   Torino                 TO
# 973        979  Five Guys     Veneto  Venezia                 VE
# 974        980  Five Guys  Lombardia   Milano                 MI
# 975        981  Five Guys   Campania   Napoli                NaN
# 976        982  Five Guys      Lazio     Roma                 RM
# 977        983  Five Guys    Toscana  Firenze                 FI
# 978        984  Five Guys     Veneto  Vicenza                 VI
# 979        985  Five Guys  Lombardia   Milano                 MI
# 980        986  Five Guys    Toscana  Firenze                 FI
# 981        987  Five Guys  Lombardia   Milano                 MI
#
#                City Menu_Category Price_Range  Customer_Rating Review_Count  \
# 972          Torino       Burgers   EUR 10-20              3.5          161
# 973         Venezia       Burgers   EUR 20-30              3.0          160
# ...

# %%
outlets.loc[outlets['Brand'].str.contains('popeyes', case=False)].shape[0]
# Out:
# 15

# %%
outlets.loc[outlets['Brand'].str.contains('popeyes', case=False), 'Brand'] = 'Popeyes'

# %%
outlets[outlets['Brand'].str.contains('popeyes', case=False)]
# Out:
#       Outlet ID    Brand          Region  Province Province_Shorthand  \
# 1135       1141  Popeyes       Lombardia    Milano                 MI
# 1136       1142  Popeyes       Lombardia    Milano                 MI
# 1137       1143  Popeyes        Piemonte    Torino                 TO
# 1138       1144  Popeyes         Abruzzo   Pescara                 PE
# 1139       1145  Popeyes       Lombardia    Milano                 MI
# 1140       1146  Popeyes       Lombardia    Milano                 MI
# 1141       1147  Popeyes        Campania   Caserta                 CE
# 1142       1148  Popeyes           Lazio      Roma                 RM
# 1143       1149  Popeyes         Toscana   Firenze                 FI
# 1144       1150  Popeyes         Sicilia   Palermo                 PA
# 1145       1151  Popeyes       Lombardia    Milano                 MI
# 1146       1152  Popeyes          Marche  Macerata                 MC
# ...

# %%
outlets.loc[outlets['Location_Type'].str.contains('transport hub -', case= False), 'Location_Type'] = "Transport Hub"

# %%
outlets[outlets['Location_Type'].str.contains('transport hub -', case=False)]
# Out:
# Empty DataFrame
# Columns: [Outlet ID, Brand, Region, Province, Province_Shorthand, City, Menu_Category, Price_Range, Customer_Rating, Review_Count, Latitude, Longitude, Location_Type, Address, Source, Unnamed: 15]
# Index: []

# %%
outlets.loc[outlets['Location_Type'].str.contains('Highway', case= False), 'Location_Type'] = 'Service Area'

# %%
outlets[outlets['Location_Type'].str.contains('highway', case= False)]
# Out:
# Empty DataFrame
# Columns: [Outlet ID, Brand, Region, Province, Province_Shorthand, City, Menu_Category, Price_Range, Customer_Rating, Review_Count, Latitude, Longitude, Location_Type, Address, Source, Unnamed: 15]
# Index: []

# %%
outlets.loc[outlets['Price_Range'].str.contains('EUR 1-60'), 'Price_Range'] = 'EUR 10-20'

# %%
outlets.loc[outlets['Price_Range'].str.contains('EUR 1-60')]
# Out:
# Empty DataFrame
# Columns: [Outlet ID, Brand, Region, Province, Province_Shorthand, City, Menu_Category, Price_Range, Customer_Rating, Review_Count, Latitude, Longitude, Location_Type, Address, Source, Unnamed: 15]
# Index: []

# %%
outlets.loc[outlets['Price_Range'].str.contains('EUR 1-20')]
# Out:
#       Outlet ID          Brand          Region               Province  \
# 1127       1133            KFC       Lombardia                 Milano
# 1249       1256    Alice Pizza          Veneto                Venezia
# 1375       1383    Alice Pizza         Toscana                  Siena
# 1722       1731  La Piadineria           Lazio                   Roma
# 1761       1770  La Piadineria       Lombardia                 Milano
# 1936       1945  La Piadineria       Lombardia  Monza e della Brianza
# 1977       1986  La Piadineria         Abruzzo                 Chieti
# 1991       2000  La Piadineria           Lazio                   Roma
# 2027       2037  La Piadineria           Lazio                   Roma
# 2028       2038  La Piadineria           Lazio                   Roma
# 2106       2116  La Piadineria          Veneto                Treviso
# 2108       2118  La Piadineria          Marche          Ascoli Piceno
# ...

# %%
outlets.loc[outlets['Outlet ID'] == 1256, 'Price_Range'] = 'EUR 1-10'
outlets.loc[outlets['Outlet ID'] == 1770, 'Price_Range'] = 'EUR 10-20'
outlets.loc[outlets['Outlet ID'] == 1945, 'Price_Range'] = 'EUR 10-20'
outlets.loc[outlets['Outlet ID'] == 2037, 'Price_Range'] = 'EUR 1-10'
outlets.loc[outlets['Outlet ID'] == 2116, 'Price_Range'] = 'EUR 1-10'
outlets.loc[outlets['Outlet ID'] == 2118, 'Price_Range'] = 'EUR 1-10'
outlets.loc[outlets['Outlet ID'] == 2157, 'Price_Range'] = 'EUR 10-20'
outlets.loc[outlets['Outlet ID'] == 2163, 'Price_Range'] = 'EUR 10-20'
outlets.loc[outlets['Outlet ID'] == 2610, 'Price_Range'] = 'EUR 10-20'

# %%
outlets.loc[outlets['Outlet ID'] == 2116]
# Out:
#       Outlet ID          Brand  Region Province Province_Shorthand  \
# 2106       2116  La Piadineria  Veneto  Treviso                 TV
#
#             City Menu_Category Price_Range  Customer_Rating Review_Count  \
# 2106  Conegliano       Piadine    EUR 1-10              4.1           61
#
#        Latitude  Longitude  Location_Type  \
# 2106  45.878554  12.315102  Shopping Mall
#
#                                                 Address  \
# 2106  Conegliano - Centro Commerciale Conè Coneglian...
#
#                                                  Source  Unnamed: 15
# 2106  https://lapiadineria.com/i-nostri-ristoranti-r...          NaN

# %%
outlets.loc[outlets['Price_Range'] == 'EUR 10-30']
# Out:
#       Outlet ID                 Brand               Region  Province  \
# 1457       1465         Old Wild West                Lazio    Latina
# 1568       1576         Old Wild West             Sardegna  Cagliari
# 1609       1617         Old Wild West               Veneto   Treviso
# 2260       2271  Roadhouse Restaurant            Lombardia    Milano
# 2314       2325  Roadhouse Restaurant                Lazio      Roma
# 2378       2389  Roadhouse Restaurant  Trentino-Alto Adige    Trento
#
#      Province_Shorthand                  City Menu_Category Price_Range  \
# 1457                 LT                Latina       Burgers   EUR 10-30
# 1568                 CA              Cagliari       Burgers   EUR 10-30
# 1609                 TV  Caerano di San Marco       Burgers   EUR 10-30
# 2260                 MI                 Arese    Steakhouse   EUR 10-30
# 2314                 RM                  Roma    Steakhouse   EUR 10-30
# ...

# %%
outlets.loc[outlets['Outlet ID'] == 1465, 'Price_Range'] = 'EUR 20-30'
outlets.loc[outlets['Outlet ID'] == 1576, 'Price_Range'] = 'EUR 20-30'
outlets.loc[outlets['Outlet ID'] == 1617, 'Price_Range'] = 'EUR 10-20'
outlets.loc[outlets['Outlet ID'] == 2325, 'Price_Range'] = 'EUR 20-30'
outlets.loc[outlets['Outlet ID'] == 2389, 'Price_Range'] = 'EUR 10-20'

# %%
outlets.loc[outlets['Outlet ID'] == 2389, 'Price_Range']
# Out:
# 2378    EUR 10-20
# Name: Price_Range, dtype: str

# %%
outlets.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2858 entries, 0 to 2857
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Outlet ID           2858 non-null   int64
#  1   Brand               2858 non-null   str
#  2   Region              2858 non-null   str
#  3   Province            2858 non-null   str
#  4   Province_Shorthand  2790 non-null   str
#  5   City                2858 non-null   str
#  6   Menu_Category       2858 non-null   str
#  7   Price_Range         2793 non-null   str
#  8   Customer_Rating     2858 non-null   float64
#  9   Review_Count        2858 non-null   str
#  10  Latitude            2858 non-null   float64
#  11  Longitude           2858 non-null   float64
#  12  Location_Type       2858 non-null   str
#  13  Address             2858 non-null   str
#  14  Source              2858 non-null   str
#  15  Unnamed: 15         0 non-null      float64
# ...

# %%
outlets['Review_Count'] = outlets['Review_Count'].astype(str).str.replace(",", "", regex= False).astype(int)

# %%
socioeconomic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Region                        20 non-null     str
#  1   Province_Count                20 non-null     int64
#  2   Region_Area                   20 non-null     str
#  3   Population                    20 non-null     int64
#  4   Population Density            20 non-null     float64
#  5   Disposable Income per capita  20 non-null     str
#  6   Total Tourism Flow            20 non-null     str
#  7   Foreign Tourism Flow          20 non-null     str
#  8   Median Income                 20 non-null     str
# dtypes: float64(1), int64(2), str(6)
# memory usage: 1.5 KB

# %%
socioeconomic['Region_Area'] = socioeconomic['Region_Area'].str.replace(",", "", regex= False).astype(float)
socioeconomic['Disposable Income per capita'] = socioeconomic['Disposable Income per capita'].str.replace(",", "", regex= False).astype(int)
socioeconomic['Total Tourism Flow'] = socioeconomic['Total Tourism Flow'].str.replace(',','',regex=False).astype(float)
socioeconomic['Foreign Tourism Flow'] = socioeconomic['Foreign Tourism Flow'].str.replace(',','',regex=False).astype(float)
socioeconomic['Median Income'] = socioeconomic['Median Income'].str.replace(',','',regex= False).astype(int)

# %%
socioeconomic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Region                        20 non-null     str
#  1   Province_Count                20 non-null     int64
#  2   Region_Area                   20 non-null     float64
#  3   Population                    20 non-null     int64
#  4   Population Density            20 non-null     float64
#  5   Disposable Income per capita  20 non-null     int64
#  6   Total Tourism Flow            20 non-null     float64
#  7   Foreign Tourism Flow          20 non-null     float64
#  8   Median Income                 20 non-null     int64
# dtypes: float64(4), int64(4), str(1)
# memory usage: 1.5 KB

# %%
duplicate_coordinate_rows = outlets[
    outlets.duplicated(
        subset=["Latitude", "Longitude"],
        keep=False
    )
].sort_values(["Latitude", "Longitude"])

#To display all the results in a scrolldown option

html_table = duplicate_coordinate_rows.loc[:, ['Outlet ID', 'Brand', 'City', 'Customer_Rating','Review_Count', 'Latitude', 'Longitude', 'Address']].to_html(index=False)

display(HTML(f"""
<div style="
    max-height: 300px;
    overflow-y: auto;
    overflow-x: auto;
    border: 1px solid #555;
    padding: 8px;
">
{html_table}
</div>
"""))
# Out:
# <div style="
#     max-height: 300px;
#     overflow-y: auto;
#     overflow-x: auto;
#     border: 1px solid #555;
#     padding: 8px;
# ">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Outlet ID</th>
#       <th>Brand</th>
#       <th>City</th>
#       <th>Customer_Rating</th>
#       <th>Review_Count</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Address</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2776</td>
#       <td>Autogrill</td>
#       <td>Enna</td>
#       <td>3.7</td>
#       <td>1882</td>
#       <td>37.577070</td>
#       <td>14.341228</td>
#       <td>Sacchitello Sud, Sud, A19 Palermo - Catania, 118, 94100 Enna EN, Italy</td>
#     </tr>
#     <tr>
#       <td>2826</td>
#       <td>Autogrill</td>
#       <td>Enna</td>
#       <td>3.7</td>
#       <td>1882</td>
#       <td>37.577070</td>
#       <td>14.341228</td>
# ...

# %%
outlets.to_csv("Data/QSR_outlet_dataset_to_clean.csv", index=False)
socioeconomic.to_csv("Data/QSR_socioeconomic_dataset_cleaned.csv", index=False)

# %%
cleaned_outlets = pd.read_csv("Data/QSR_outlet_dataset_cleaned.csv", keep_default_na=False)

# %%
#Duplicates by Coordinate
duplicate_coordinate_rows = cleaned_outlets[
    cleaned_outlets.duplicated(
        subset=["Latitude", "Longitude"],
        keep=False
    )
].sort_values(["Latitude", "Longitude"])

#To display all the results in a scrolldown option

html_table = duplicate_coordinate_rows.loc[:, ['Outlet ID', 'Brand', 'City', 'Customer_Rating','Review_Count', 'Latitude', 'Longitude', 'Address']].to_html(index=False)

display(HTML(f"""
<div style="
    max-height: 300px;
    overflow-y: auto;
    overflow-x: auto;
    border: 1px solid #555;
    padding: 8px;
">
{html_table}
</div>
"""))
# Out:
# <div style="
#     max-height: 300px;
#     overflow-y: auto;
#     overflow-x: auto;
#     border: 1px solid #555;
#     padding: 8px;
# ">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Outlet ID</th>
#       <th>Brand</th>
#       <th>City</th>
#       <th>Customer_Rating</th>
#       <th>Review_Count</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Address</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
#By brand, address and city

duplicate_coordinate_rows = cleaned_outlets[
    cleaned_outlets.duplicated(
        subset=["Brand", "City", "Address"],
        keep=False
    )
].sort_values(["Brand"])

#To display all the results in a scrolldown option
from IPython.display import display, HTML

html_table = duplicate_coordinate_rows.loc[:, ['Outlet ID', 'Brand', 'City', 'Customer_Rating','Review_Count', 'Latitude', 'Longitude', 'Address']].to_html(index=False)

display(HTML(f"""
<div style="
    max-height: 300px;
    overflow-y: auto;
    overflow-x: auto;
    border: 1px solid #555;
    padding: 8px;
">
{html_table}
</div>
"""))
# Out:
# <div style="
#     max-height: 300px;
#     overflow-y: auto;
#     overflow-x: auto;
#     border: 1px solid #555;
#     padding: 8px;
# ">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Outlet ID</th>
#       <th>Brand</th>
#       <th>City</th>
#       <th>Customer_Rating</th>
#       <th>Review_Count</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Address</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
#For the missing Price_Range values

cleaned_outlets["Price_Range_Cleaned"] = (
    cleaned_outlets["Price_Range"]
    .replace("", pd.NA)
    .replace(["EUR 1-20", "EUR 10-30", "EUR 1-30"], pd.NA)
)

# %%
brand_price_mode = (
    cleaned_outlets
    .dropna(subset=["Price_Range_Cleaned"])
    .groupby("Brand")["Price_Range_Cleaned"]
    .agg(lambda x: x.mode().iloc[0])
)

brand_price_mode
# Out:
# Brand
# Alice Pizza              EUR 1-10
# Autogrill                EUR 1-10
# Billy Tacos             EUR 10-20
# Burger King             EUR 10-20
# Burgez                  EUR 10-20
# Chef Express             EUR 1-10
# Five Guys               EUR 10-20
# KFC                     EUR 10-20
# La Piadineria            EUR 1-10
# McDonald's              EUR 10-20
# Old Wild West           EUR 10-20
# Popeyes                 EUR 10-20
# Roadhouse Restaurant    EUR 20-30
# Spizzico                EUR 10-20
# Spontini                EUR 10-20
# Starbucks                EUR 1-10
# Subway                   EUR 1-10
# Name: Price_Range_Cleaned, dtype: str

# %%
# Is imputed

cleaned_outlets["Price_Range_Imputed"] = cleaned_outlets["Price_Range_Cleaned"].isna()

html_table = cleaned_outlets.loc[:, ['Outlet ID','Brand', 'Price_Range_Imputed']].to_html(index=False)

display(HTML(f"""
<div style="
    max-height: 300px;
    overflow-y: auto;
    overflow-x: auto;
    border: 1px solid #555;
    padding: 8px;
">
{html_table}
</div>
"""))
# Out:
# <div style="
#     max-height: 300px;
#     overflow-y: auto;
#     overflow-x: auto;
#     border: 1px solid #555;
#     padding: 8px;
# ">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Outlet ID</th>
#       <th>Brand</th>
#       <th>Price_Range_Imputed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>McDonald's</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>McDonald's</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>McDonald's</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>McDonald's</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>McDonald's</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>McDonald's</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>McDonald's</td>
#       <td>False</td>
# ...

# %%
cleaned_outlets["Price_Range_Cleaned"] = cleaned_outlets["Price_Range_Cleaned"].fillna(
    cleaned_outlets["Brand"].map(brand_price_mode)
)

# %%
cleaned_outlets.to_csv("Data/QSR_outlet_dataset_cleaned.csv", index=False)
